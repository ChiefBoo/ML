# %% [markdown]
# ## Лабораторная работа №1
#
# Ссылка на Data set: https://www.kaggle.com/ronitf/heart-disease-uci

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('heart.csv')  #загружаем данные

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Attribute Information:
# > 1. age (возраст)
# > 2. sex (values 0,1) (пол: 1 - мужчина, 0 - женщина)
# > 3. cp => chest pain type (4 values: 0,1,2,3) (тип боли в груди)
# > 4. trestbps => resting blood pressure (артериальное давление в покое)
# > 5. chol => serum cholestoral in mg/dl  ((холестерин)
# > 6. fbs => fasting blood sugar > 120 mg/dl (values 0,1) (уровень сахара в крови > 120)
# > 7. restecg => resting electrocardiographic results (values 0,1,2)(результаты ЭКГ в покое)
# > 8. thalach => maximum heart rate achieved (макс. частота сердечных сокращений)
# > 9. exang => exercise induced angina (values 0,1) (стенокардия, вызванная физ. упр.: 1 - да, 0 - нет)
# > 10. oldpeak => ST depression induced by exercise relative to rest (депрессия St, вызванная физ. упр.)
# > 11. slope => the slope of the peak exercise ST segment (values 0,1,2) (наклон сегмента ST)
# > 12. ca => number of major vessels (0-3) colored by flourosopy (количество крупных сосудов)
# > 13. thal => 2 = normal; 1 = fixed defect; 3 = reversable defect (состояние)
# >14. target =>  0 = disease, 1 = no disease. (Итог: 0 - болезнь, 1 - нет болезни)

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
print(data.shape)
print(data.columns)
# Out:
# (303, 14)
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
data.at[34, 'age']
# Out:
# 51

# %%
data['age'][3]
# Out:
# 56

# %%
data['cp'].dtype.name
# Out:
# 'int64'

# %%
type(data['oldpeak'])
# Out:
# pandas.core.series.Series

# %%
data[['age', 'cp']].head()
# Out:
#    age  cp
# 0   63   3
# 1   37   2
# 2   41   1
# 3   56   1
# 4   57   0

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
pd.plotting.scatter_matrix(data, alpha = .01, figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
plt.plot(data['age'], data['trestbps'], 'o', alpha = 0.15)
plt.xlabel('age')
plt.ylabel('trestbps')
plt.title('Age vs trestbps')
pass

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['target'] == 0]['cp'],
            data[data['target'] == 0]['age'],
            alpha = 0.25,
            label = 'disease',
            color = 'r')

plt.scatter(data[data['target'] == 1]['cp'],
            data[data['target'] == 1]['age'],
            alpha = 0.15,
            label = 'no disease',
            color = 'b')

plt.xlabel('cp')
plt.xticks(range(-1,4))
plt.xlim(-1,4)
plt.ylabel('age')
plt.legend()
plt.grid()

# %%
np.random.seed(0)
age_rnd = data['age'] + np.random.rand(data.shape[0]) - .5
plt.figure(figsize = (10, 8))

plt.scatter(age_rnd[data['target'] == 0],
            data[data['target'] == 0]['cp'],
            alpha = 0.25,
            label = 'disease',
            color = 'r')

plt.scatter(age_rnd[data['target'] == 1],
            data[data['target'] == 1]['cp'],
            alpha = 0.25,
            label = 'no disease',
            color = 'b')

plt.xlabel('age')
plt.xticks(range(20,90))
plt.xlim(20,90)
plt.ylabel('cp')
plt.title('Data')
plt.grid()

# %%
plt.scatter(data[data['target'] == 1]['cp'],
            data[data['target'] == 1]['thalach'],
            alpha = 0.15,
            label = 'no disease',
            color = 'b')

plt.scatter(data[data['target'] == 0]['cp'],
            data[data['target'] == 0]['thalach'],
            alpha = 0.15,
            label = 'disease',
            color = 'r')

plt.xlabel('cp')
plt.ylabel('thalach')
plt.grid()

# %%
data.describe(include = 'all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data['target'].unique()
# Out:
# array([1, 0])

# %%
data['cp'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
data['ca'].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
for value in data['cp'].unique():
    print(value, data['sex'][data['cp'] == value].iloc[0])
# Out:
# 3 1
# 2 1
# 1 0
# 0 0

# %% [markdown]
# ##  Работа с данными

# %%
data['cp'].dtype.name
# Out:
# 'int64'

# %%
data['oldpeak'].dtype.name
# Out:
# 'float64'

# %%
data.median(axis = 0)
# Out:
# age          55.0
# sex           1.0
# cp            1.0
# trestbps    130.0
# chol        240.0
# fbs           0.0
# restecg       1.0
# thalach     153.0
# exang         0.0
# oldpeak       0.8
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# dtype: float64

# %%
data.count(axis = 0)
# Out:
# age         303
# sex         303
# cp          303
# trestbps    303
# chol        303
# fbs         303
# restecg     303
# thalach     303
# exang       303
# oldpeak     303
# slope       303
# ca          303
# thal        303
# target      303
# dtype: int64

# %%
data['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
type(data['trestbps'].describe())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Векторизация и пропущенные значения

# %%
#все данные уже заданы в численном варианте, но есть "плохие" данные: не те значения, которые требуются.
#Необходимо либо удалить строки содержащие эти данные, либо изменить на средние значения.

data['thal'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
data.loc[(data['thal'] == 0), 'thal'] = 2

# %%
data['thal'].unique()
# Out:
# array([1, 2, 3])

# %%
data['ca'].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
data.loc[(data['ca'] == 4), 'ca'] = 0

# %%
data['ca'].unique()
# Out:
# array([0, 2, 1, 3])

# %% [markdown]
# ### Нормализация количественных признаков

# %%
numerical_columns   = [c for c in data.columns if len(data[c].unique()) > 4]
no_numerical_columns = [c for c in data.columns if len(data[c].unique()) <= 4]
print(numerical_columns)
print(no_numerical_columns)

data_no_numerical = data[no_numerical_columns]
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']
#               age    trestbps        chol     thalach     oldpeak
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    1.039604
# std      9.082101   17.538143   51.830751   22.905161    1.161075
# min     29.000000   94.000000  126.000000   71.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.800000
# 75%     61.000000  140.000000  274.500000  166.000000    1.600000
# max     77.000000  200.000000  564.000000  202.000000    6.200000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()
# Out:
#                 age      trestbps          chol       thalach       oldpeak
# count  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02
# mean   1.315413e-16 -7.526066e-16 -8.839647e-17 -5.466841e-16  1.586556e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.793003e+00 -2.145254e+00 -2.320322e+00 -3.433587e+00 -8.953805e-01
# 25%   -7.560295e-01 -6.627704e-01 -6.803688e-01 -7.049444e-01 -8.953805e-01
# 50%    6.977057e-02 -9.258463e-02 -1.208554e-01  1.463921e-01 -2.063639e-01
# 75%    7.304107e-01  4.776012e-01  5.447726e-01  7.139498e-01  4.826527e-01
# max    2.492118e+00  3.898716e+00  6.130260e+00  2.285648e+00  4.444498e+00

# %%
data = pd.concat((data_numerical,data_no_numerical),axis = 1)
print(data.shape)
# Out:
# (303, 14)

# %%
data
# Out:
#           age  trestbps      chol   thalach   oldpeak  sex  cp  fbs  restecg  \
# 0    0.950624  0.762694 -0.255910  0.015417  1.085542    1   3    1        0
# 1   -1.912150 -0.092585  0.072080  1.630774  2.119067    1   2    0        1
# 2   -1.471723 -0.092585 -0.815424  0.975900  0.310399    0   1    0        0
# 3    0.179877 -0.662770 -0.198030  1.237849 -0.206364    1   1    0        1
# 4    0.289984 -0.662770  2.078611  0.582975 -0.378618    0   0    0        1
# 5    0.289984  0.477601 -1.046947 -0.071899 -0.550872    1   0    0        1
# 6    0.179877  0.477601  0.920997  0.146392  0.224272    0   1    0        0
# 7   -1.141403 -0.662770  0.322897  1.019558 -0.895381    1   1    0        1
# 8   -0.260549  2.302196 -0.911892  0.539317 -0.464745    1   2    1        1
# 9    0.289984  1.047787 -1.509992  1.063216  0.482653    1   2    0        1
# 10  -0.040336  0.477601 -0.140149  0.452000  0.138144    1   0    0        1
# ...

# %%
data.describe()
# Out:
#                 age      trestbps          chol       thalach       oldpeak  \
# count  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02
# mean   1.315413e-16 -7.526066e-16 -8.839647e-17 -5.466841e-16  1.586556e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.793003e+00 -2.145254e+00 -2.320322e+00 -3.433587e+00 -8.953805e-01
# 25%   -7.560295e-01 -6.627704e-01 -6.803688e-01 -7.049444e-01 -8.953805e-01
# 50%    6.977057e-02 -9.258463e-02 -1.208554e-01  1.463921e-01 -2.063639e-01
# 75%    7.304107e-01  4.776012e-01  5.447726e-01  7.139498e-01  4.826527e-01
# max    2.492118e+00  3.898716e+00  6.130260e+00  2.285648e+00  4.444498e+00
#
#               sex          cp         fbs     restecg       exang       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.683168    0.966997    0.148515    0.528053    0.326733    1.399340
# ...

# %% [markdown]
# ### X и y

# %%
X = data.drop(('target'), axis = 1) #выбрасываем столбец 'target'
y = data['target']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'sex', 'cp', 'fbs',
#        'restecg', 'exang', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
# Out:
# (303, 13)
# (303,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Разбиваем на тестовую и тренировочную выборки

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 212 91

# %%
212 + 91
# Out:
# 303

# %% [markdown]
# ## kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print('Train error: {}  Test error: {}'.format(err_train, err_test))
# Out:
# Train error: 0.16037735849056603  Test error: 0.17582417582417584

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ
err_test
# Out:
# 0.17582417582417587

# %%
from sklearn.metrics import confusion_matrix
print("confusion_matrix_testn =\n",confusion_matrix(y_test, y_test_predict))
# Out:
# confusion_matrix_testn =
#  [[33  8]
#  [ 8 42]]

# %%
from sklearn.metrics import confusion_matrix
print("confusion_matrix_train =\n",confusion_matrix(y_train, y_train_predict))
# Out:
# confusion_matrix_train =
#  [[ 74  23]
#  [ 11 104]]

# %% [markdown]
# Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.18867924528301883 5
# /home/boo/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print('Train error: {}  Test error: {}'.format(err_train, err_test))
# Out:
# Train error: 0.12264150943396226  Test error: 0.15384615384615385

# %% [markdown]
# По тренировочной выборке найдено оптимальное значение k = 5,  а ошибка на тестовой выборке равно 0.15384615384615385

# %% [markdown]
# ## Лабораторная работа №2
# ### PCA

# %% [markdown]
# применяем PCA для сокращения размерности пространства признаков

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X_train)
principalDf = pd.DataFrame(data = principalComponents
            , columns = ['first attribute', 'second attribute'])
principalDf
# Out:
#      first attribute  second attribute
# 0         -50.644956        -33.626587
# 1         -44.188579        -55.180037
# 2         -28.946893         -9.084801
# 3          -7.794314         -8.866437
# 4         -72.413210        -24.208994
# 5         -50.120134         19.860220
# 6         -15.532154          1.001400
# 7         -28.178408        -21.988142
# 8          61.632579         19.535607
# 9         -14.254814        -12.911234
# 10         92.164520        -22.451457
# 11        -44.496952          4.522386
# 12         69.829488          8.732731
# 13        -14.658879         -7.340499
# 14        -13.638431        -26.007648
# 15         -3.991188        -13.238105
# 16        -38.187309        -11.298455
# 17        -70.256426         11.764927
# 18        -71.261363         27.219898
# 19        -27.530693         -3.895824
# 20         -5.765102         -5.001228
# 21        -59.322019          9.064337
# 22          0.253138        -20.982049
# ...

# %%
finalDf = pd.concat([principalDf, pd.DataFrame(data = np.array(y)
             , columns = ['target'])], axis = 1)
finalDf
# Out:
#      first attribute  second attribute  target
# 0         -50.644956        -33.626587       1
# 1         -44.188579        -55.180037       1
# 2         -28.946893         -9.084801       1
# 3          -7.794314         -8.866437       1
# 4         -72.413210        -24.208994       1
# 5         -50.120134         19.860220       1
# 6         -15.532154          1.001400       1
# 7         -28.178408        -21.988142       1
# 8          61.632579         19.535607       1
# 9         -14.254814        -12.911234       1
# 10         92.164520        -22.451457       1
# 11        -44.496952          4.522386       1
# 12         69.829488          8.732731       1
# 13        -14.658879         -7.340499       1
# 14        -13.638431        -26.007648       1
# 15         -3.991188        -13.238105       1
# 16        -38.187309        -11.298455       1
# 17        -70.256426         11.764927       1
# 18        -71.261363         27.219898       1
# ...

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('first attribute', fontsize = 15)
ax.set_ylabel('second attribute', fontsize = 15)
ax.set_title('2 attribute PCA', fontsize = 20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'first attribute']
               , finalDf.loc[indicesToKeep, 'second attribute']
               , c = color
               , s = 50)
ax.legend(['disease', 'no disease'])
ax.grid()

# %%
plt.scatter(pcaDuo[:,0], pcaDuo[:,1], color = 'b', alpha = .2)
plt.grid()
plt.xlabel('first attribute')
plt.ylabel('second attribute')
plt.title('2 attribute PCA')
# Out:
# Text(0.5, 1.0, '2 attribute PCA')

# %% [markdown]
# применяем KNN при k = 5

# %%
X_train, X_test, y_train, y_test = train_test_split(pcaDuo, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 212 91

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print('Train error: {}  Test error: {}'.format(err_train, err_test))
# Out:
# Train error: 0.1650943396226415  Test error: 0.1978021978021978

# %% [markdown]
# Значение ошибок на выборках стало хуже. Было Train error: 0.12264150943396226  Test error: 0.15384615384615385
#
#
# График

# %%
comp = range(1, 14, 1)
err_train_mas = []
err_test_mas = []
for temp in comp:
    pca = PCA(n_components = temp)
    pcaFit = pca.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(pcaFit, y, test_size = 0.3, random_state = 42)
    knn = KNeighborsClassifier(n_neighbors = 5).fit(X_train, y_train)
    err_train_mas.append(np.mean(knn.predict(X_train) != y_train))
    err_test_mas.append(np.mean(knn.predict(X_test) != y_test))
plt.plot(comp, err_train_mas, 'r-o', label = 'Train error')
plt.plot(comp, err_test_mas,  'b-o', label = 'Test error')    
plt.legend(loc = 2)

# %%
min_err = min(err_test_mas)
min_err_index = err_test_mas.index(min(err_test_mas))
print("Min error test: " + str(min_err))
n_components_best = comp[min_err_index]
print("Best number of components: " + str(n_components_best))
print("Error train: " + str(err_train_mas[min_err_index]))
# Out:
# Min error test: 0.14285714285714285
# Best number of components: 11
# Error train: 0.12264150943396226

# %%
min_err_train = min(err_train_mas)
min_err_index_train = err_train_mas.index(min(err_train_mas))
print("Min error train: " + str(min_err_train))
n_components_best = comp[min_err_index_train]
print("Best number of components: " + str(n_components_best))
print("Error test: " + str(err_test_mas[min_err_index_train]))
# Out:
# Min error train: 0.11320754716981132
# Best number of components: 10
# Error test: 0.17582417582417584

# %% [raw]
# Вывод: Наилучшее значение количества используемых главных компонент - 11, т.к при 11 компонентах достигается минимальная тестовая ошибка, но не минимальная для тренировочной выборки - для нее 10 компонент. PCA позволил снизить ошибку на тестовой выборке. До этого были такие результаты:
# 0.12264150943396226 Test error: 0.15384615384615385

# %% [markdown]
# # Другие алгоритмы

# %%
#SVC

from sklearn.svm import SVC
svc = SVC(gamma='auto')
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.08962264150943396 0.16483516483516483

# %%
from sklearn.model_selection import GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC(gamma='auto')
grid = GridSearchCV(svc, cv=3, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# 0.160377358490566 1000.0
# /home/boo/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
svc = SVC(C = best_C, gamma='auto').fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.12264150943396226 0.15384615384615385

# %%
#Random Forest

from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.18681318681318682

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0000000000000002

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
d = 13
print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature '  age' (0.232680)
#  2. feature '  fbs' (0.139020)
#  3. feature '  sex' (0.107463)
#  4. feature 'trestbps' (0.095022)
#  5. feature '   ca' (0.059753)
#  6. feature 'thalach' (0.055987)
#  7. feature 'slope' (0.052664)
#  8. feature ' thal' (0.052618)
#  9. feature ' chol' (0.044433)
# 10. feature 'restecg' (0.042328)
# 11. feature 'oldpeak' (0.041417)
# 12. feature '   cp' (0.040419)
# 13. feature 'exang' (0.036197)

# %%
feature_names[[1, 0, 1]]
# Out:
# Index(['trestbps', 'age', 'trestbps'], dtype='object')

# %%
d_first = 13
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 13)

# %%
#Extremely Randomized Trees

ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.16483516483516483

# %%
#AdaBoost

ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.24175824175824176

# %%
#GBT

gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.18681318681318682

# %% [markdown]
# ## Лабораторная работа №3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('heart.csv')  #загрузка данных

# %%
data['thal'].unique()
data.loc[(data['thal'] == 0), 'thal'] = 2  # поправляем данные
data.loc[(data['ca'] == 4), 'ca'] = 0

# %%
#нормализация
numerical_columns   = [c for c in data.columns if len(data[c].unique()) > 4]
no_numerical_columns = [c for c in data.columns if len(data[c].unique()) <= 4]

data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)
data_numerical.describe()

data_no_numerical = data[no_numerical_columns]
data_numerical = data[numerical_columns]
data_numerical.describe()

data = pd.concat((data_numerical,data_no_numerical),axis = 1)
print(data.shape)
# Out:
# (303, 14)

# %%
X = data.drop(('target'), axis = 1) #выбрасываем столбец 'target'
y = data['target']
feature_names = X.columns

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 212 91

# %% [markdown]
# ### Полносвязная нейронная сеть

# %%
from sklearn.neural_network import MLPClassifier

mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %% [markdown]
# Ошибки классификатора

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)


print('Train err: {}, Test err: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train err: 0.2028301886792453, Test err: 0.3956043956043956

# %% [markdown]
# Подбор параметра альфа

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'test')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# При увеличении альфа в определенный момент ошибка на тестовой выборке начинает превосходить ошибку на тренировочной => получается переобучение

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
alpha_opt = alpha_arr[test_err == min_test_err][0]

print('Min train error: {}, Min test error: {}'.format(min_train_err, min_test_err))
print('Alpha: ', alpha_opt)
# Out:
# Min train error: 0.14622641509433962, Min test error: 0.16483516483516483
# Alpha:  5.623413251903491

# %% [markdown]
# Классификатор при оптимальном альфа

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (100,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print('Train error: {}, Test error: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train error: 0.2169811320754717, Test error: 0.16483516483516483

# %% [markdown]
# Ошибка на тестовой выборке уменьшилась

# %% [markdown]
# Подбор числа нейронов на 1 скрытом слое

# %%
neurons_arr = np.arange(10,150, 5)
test_err = []
train_err = []
for neuron in neurons_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron, 50), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(neurons_arr, train_err, 'b-o', label = 'test')
plt.semilogx(neurons_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(neurons_arr), np.min(neurons_arr)])
plt.title('Error vs. neuron')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Классификатор с оптимальным значением нейронов

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
neuron_opt = neurons_arr[test_err == min_test_err][0]

print('Min train error: {}, \tMin test error: {}'.format(min_train_err, min_test_err))
print('Neuron: ', neuron_opt)
# Out:
# Min train error: 0.3018867924528302, 	Min test error: 0.2087912087912088
# Neuron:  140

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neuron_opt, 50),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

print('Train error: {}, Test error: {}'.format(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)))
# Out:
# Train error: 0.3018867924528302, Test error: 0.2087912087912088

# %% [markdown]
# Наблюдается переобучение, т.к ошибка на тестовой меньше, чем ошибка на тренировочной выборке.

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

estimators = np.arange(500,1500, 100)
test_err = []
train_err = []
oob_score = []
for estimator in estimators:
    rf = RandomForestClassifier(n_estimators = estimator, random_state = 42, oob_score=True)
    rf.fit(X_train, y_train)

    y_train_pred = rf.predict(X_train)
    y_test_pred = rf.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    oob_score.append(rf.oob_score_)

# %%
plt.semilogx(estimators, train_err, 'b-o', label = 'train')
plt.semilogx(estimators, test_err, 'r-o', label = 'test')
plt.semilogx(estimators, np.ones(len(oob_score))-oob_score, 'g-o', label = 'oob-error')
plt.xlim([np.max(estimators), np.min(estimators)])
plt.title('Error vs. estimators')
plt.xlabel('estimators')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
estimators_opt = estimators[test_err == min_test_err][0]

print('Min train error: {}, Min test error: {}'.format(min_train_err, min_test_err))
print('Estimators: ', estimators_opt)
# Out:
# Min train error: 0.0, Min test error: 0.18681318681318682
# Estimators:  900

# %% [markdown]
# ###  Gradient boosted trees

# %%
from sklearn.ensemble import GradientBoostingClassifier

estimators = np.arange(900,1200, 100)
test_err = []
train_err = []
for estimator in estimators:
    gbt = GradientBoostingClassifier(n_estimators = estimator, random_state = 42)
    gbt.fit(X_train, y_train)

    y_train_pred = gbt.predict(X_train)
    y_test_pred = gbt.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(estimators, train_err, 'b-o', label = 'train')
plt.semilogx(estimators, test_err, 'r-o', label = 'test')
plt.xlim([np.max(estimators), np.min(estimators)])
plt.title('Error vs. estimators')
plt.xlabel('estimators')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
estimators_opt = estimators[test_err == min_test_err][0]

print('Min train error: {}, \tMin test error: {}'.format(min_train_err, min_test_err))
print('Estimators: ', estimators_opt)
# Out:
# Min train error: 0.0, 	Min test error: 0.23076923076923078
# Estimators:  900
